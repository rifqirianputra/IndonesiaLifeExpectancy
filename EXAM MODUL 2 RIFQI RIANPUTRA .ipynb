# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('WHO.csv')

# %%
df
# Out:
#           Country  Year      Status  Life expectancy   Adult Mortality  \
# 0     Afghanistan  2015  Developing              65.0            263.0
# 1     Afghanistan  2014  Developing              59.9            271.0
# 2     Afghanistan  2013  Developing              59.9            268.0
# 3     Afghanistan  2012  Developing              59.5            272.0
# 4     Afghanistan  2011  Developing              59.2            275.0
# ...           ...   ...         ...               ...              ...
# 2933     Zimbabwe  2004  Developing              44.3            723.0
# 2934     Zimbabwe  2003  Developing              44.5            715.0
# 2935     Zimbabwe  2002  Developing              44.8             73.0
# 2936     Zimbabwe  2001  Developing              45.3            686.0
# 2937     Zimbabwe  2000  Developing              46.0            665.0
#
#       infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   \
# ...

# %%
x = df['Status']
y = df['Life expectancy ']

# %%
dfindo = df[(df['Country']=="Indonesia")]
dfindo.isna().sum()
# Out:
# Country                            0
# Year                               0
# Status                             0
# Life expectancy                    0
# Adult Mortality                    0
# infant deaths                      0
# Alcohol                            1
# percentage expenditure             0
# Hepatitis B                        0
# Measles                            0
#  BMI                               0
# under-five deaths                  0
# Polio                              0
# Total expenditure                  1
# Diphtheria                         0
#  HIV/AIDS                          0
# GDP                                0
# Population                         0
#  thinness  1-19 years              0
#  thinness 5-9 years                0
# Income composition of resources    0
# Schooling                          0
# dtype: int64

# %%
"dari data diatas, hanya terdapat 2 file NaN"
# Out:
# 'dari data diatas, hanya terdapat 2 file NaN'

# %%
"dari data diatas, secara life expectancy, kita mlihat bahwa Indonesia mengalami peningkatan Life Expectancy selama 15 tahun belakangan ini.."
"explorasi data ini dilakukan untuk mengetahui apa faktor apa yang paling berpengaruh terhadap peningkatan life expectancy tersebut agar negara dapat melakukan efisiensi dari sisi APBN maupun APBD agar tepat sasaran dalam meningkatkan angka harapan hidup"
# Out:
# 'explorasi data ini dilakukan untuk mengetahui apa faktor apa yang paling berpengaruh terhadap peningkatan life expectancy tersebut agar negara dapat melakukan efisiensi dari sisi APBN maupun APBD agar tepat sasaran dalam meningkatkan angka harapan hidup'

# %%
P = sns.PairGrid(dfindo)
P.map(plt.scatter)

# %%
"dari data diatas, ada beberapa variabel yang menarik untuk dieksplorasi lebih mendalam, diantaranya: Adult Mortality, Infant Death, Under5 Death, Income Composition of Resource, dan Schooling"
# Out:
# 'dari data diatas, ada beberapa variabel yang menarik untuk dieksplorasi lebih mendalam, diantaranya: Adult Mortality, Infant Death, Under5 Death, Income Composition of Resource, dan Schooling'

# %%
dfindo['Year'] = pd.to_datetime(dfindo['Year'], format="%Y")
x = dfindo ['Year']
y1 = dfindo['Adult Mortality']
y2 = dfindo['infant deaths']
y3 = dfindo['under-five deaths ']
y4 = dfindo['Income composition of resources']
y5 = dfindo['Schooling']
y6 = dfindo['Hepatitis B']
y7 = dfindo['Measles ']
y8 = dfindo['Polio']
y9 = dfindo['Diphtheria ']
y10 = dfindo[' HIV/AIDS']

# %%
sns.lmplot(x='Life expectancy ', y='Adult Mortality' ,data=dfindo)

# %%
"walaupun tidak terlalu signifikan, kematian dewasa memiliki korelasi negatif terhadap angka harapan hidup"

# %%
sns.lmplot(x='Life expectancy ', y='infant deaths' ,data=dfindo)

# %%
"dengan hubungan yang kuat, kematian bayi memiliki korelasi negatif terhadap angka harapan hidup"

# %%
sns.lmplot(x='Life expectancy ', y='under-five deaths ' ,data=dfindo)

# %%
"dengan hubungan yang kuat, kematian balita memiliki korelasi negatif terhadap angka harapan hidup"

# %%
sns.lmplot(x='Life expectancy ', y='Income composition of resources' ,data=dfindo)

# %%
"dengan hubungan yang kuat, composition income of resources memiliki korelasi positif terhadap angka harapan hidup"

# %%
sns.lmplot(x='Life expectancy ', y='Schooling' ,data=dfindo)

# %%
"dengan hubungan yang kuat, Schooling memiliki korelasi positif terhadap angka harapan hidup"

# %%
plt.figure(figsize=(15,10))
plt.plot(x,y1,'g',x,y2,'c',x,y3,'b')
plt.title('Angka Kematian dari Tahun ke Tahun')
plt.xlabel('Tahun')
plt.ylabel('Kematian')
plt.grid(True)
plt.legend(['Kematian Dewasa','Kematian Bayi','Kematian Balita'])

# %%
"dari tahun ke tahun, Indonesia mengalami penurunan jumlah kematian secara konstan"
"namun, terdapat 2 kali drop dalam Angka kematian dewasa, sehingga dapat dikatakan bahwa data yang dimiliki WHO tidak lengkap, atau Indonesia tidak memberikan data lengkap"
"walaupun terdapat 2x drop dalam grafik, secara garis besar, arah jumlah kematian terus menurut dari tahun ke tahun.."
# Out:
# 'namun, terdapat 2 kali drop dalam Angka kematian dewasa, sehingga dapat dikatakan bahwa data yang dimiliki WHO tidak lengkap, atau Indonesia tidak memberikan data lengkap'

# %%
plt.figure(figsize=(15,10))
plt.plot(x,y5,'c')
plt.title('Angka Masuk Sekolah dari tahun ke tahun')
plt.xlabel('Tahun')
plt.ylabel('Angka Masuk Sekolah')
plt.grid(True)
plt.legend(['Schooling'])

# %%
plt.figure(figsize=(15,10))
plt.plot(x,y4,'g')
plt.title('Angka Komposisi Total Income')
plt.xlabel('Tahun')
plt.ylabel('Income')
plt.grid(True)
plt.legend(['Income composition of resources'])

# %%
"kedua variabel tersebut merupakan variabel yang memiliki hubungan positif terhadap kenaikan angka harapan hidup di Indonesia"
"sehingga, Indonesia dapat fokus untuk mengalokasikan APBN dan APBD terhadap 2 sektor tersebut, yaitu sektor pendidikan dan sektor keuangan"

"mwngutip NewScientist: https://www.newscientist.com/article/2166833-more-education-is-what-makes-people-live-longer-not-more-money/"
"Rüdiger Krech dari WHO mengatakan bahwa pendidikan adalah faktor utama dalam kesehatan dan pendidikan akan menjadi lebih penting lagi dalam kesehatan, dimana contohnya adalah Diabetes yang sangat dipengaruhi oleh pilihan gaya hidup"
# Out:
# 'Rüdiger Krech dari WHO mengatakan bahwa pendidikan adalah faktor utama dalam kesehatan dan pendidikan akan menjadi lebih penting lagi dalam kesehatan, dimana contohnya adalah Diabetes yang sangat dipengaruhi oleh pilihan gaya hidup'

# %%
"lalu, bagaimana indonesia apabila dikomparasi dengan negara lain?"
# Out:
# 'lalu, bagaimana indonesia apabila dikomparasi dengan negara lain?'

# %%
dfMYS = df[(df['Country']=="Malaysia")]
dfMYS['Year'] = pd.to_datetime(dfMYS['Year'], format="%Y")
dfPHL = df[(df['Country']=="Philippines")]
dfPHL['Year'] = pd.to_datetime(dfPHL['Year'], format="%Y")
dfSGP = df[(df['Country']=="Singapore")]
dfSGP['Year'] = pd.to_datetime(dfSGP['Year'], format="%Y")
dfTHA = df[(df['Country']=="Thailand")]
dfTHA['Year'] = pd.to_datetime(dfTHA['Year'], format="%Y")
dfKHM = df[(df['Country']=="Cambodia")]
dfKHM['Year'] = pd.to_datetime(dfKHM['Year'], format="%Y")

# %%
dfVNM
# Out:
# Empty DataFrame
# Columns: [Country, Year, Status, Life expectancy , Adult Mortality, infant deaths, Alcohol, percentage expenditure, Hepatitis B, Measles ,  BMI , under-five deaths , Polio, Total expenditure, Diphtheria ,  HIV/AIDS, GDP, Population,  thinness  1-19 years,  thinness 5-9 years, Income composition of resources, Schooling]
# Index: []
#
# [0 rows x 22 columns]

# %%
x = dfindo ['Year']
yM1 = dfMYS['Adult Mortality']
yM2 = dfMYS['infant deaths']
yM3 = dfMYS['under-five deaths ']
yM4= dfMYS['Income composition of resources']
yM5 = dfMYS['Schooling']
yP1 = dfPHL['Adult Mortality']
yP2 = dfPHL['infant deaths']
yP3 = dfPHL['under-five deaths ']
yP4= dfPHL['Income composition of resources']
yP5 = dfPHL['Schooling']
yS1 = dfSGP['Adult Mortality']
yS2 = dfSGP['infant deaths']
yS3 = dfSGP['under-five deaths ']
yS4= dfSGP['Income composition of resources']
yS5 = dfSGP['Schooling']
yT1 = dfTHA['Adult Mortality']
yT2 = dfTHA['infant deaths']
yT3 = dfTHA['under-five deaths ']
yT4= dfTHA['Income composition of resources']
yT5 = dfTHA['Schooling']
yK1 = dfKHM['Adult Mortality']
yK2 = dfKHM['infant deaths']
yK3 = dfKHM['under-five deaths ']
yK4= dfKHM['Income composition of resources']
yK5 = dfKHM['Schooling']

# %%
plt.figure(figsize=(15,10))
plt.plot(x,y1,'r',x,yM1,'g',x,yP1,'c',x,yS1,'b',x,yT1,'k',x,yK1,'y')
plt.title('Angka Kematian Dewasa dari tahun ke tahun')
plt.xlabel('Tahun')
plt.ylabel('Kematian Dewasa')
plt.grid(True)
plt.legend(['Indonesia','Malaysia','Filipina','Singapura','Thailand','Kamboja'])

# %%
"Pada tahun 2000-2006, Indoneisa bukan negara dengan angka kematian dewasa tertinggi. namun, Kamboja dapat menurunkan angka kematian dengan lebih cepat ketimbang Indonesia dan Filipina"
"Singapura memiliki angka kematian terendah selama 15 tahun terakhir dibandingkan dengan negara-negara tetangganya."
# Out:
# 'Pada tahun 2000-2006, Indoneisa bukan negara dengan angka kematian dewasa tertinggi. namun, Kamboja dapat menurunkan angka kematian dengan lebih cepat ketimbang Indonesia dan Filipina'

# %%
plt.figure(figsize=(15,10))
plt.plot(x,y2,'r',x,yM2,'g',x,yP2,'c',x,yS2,'b',x,yT2,'k',x,yK2,'y')
plt.title('Angka Kematian Bayi dari tahun ke tahun')
plt.xlabel('Tahun')
plt.ylabel('Kematian Bayi')
plt.grid(True)
plt.legend(['Indonesia','Malaysia','Filipina','Singapura','Thailand','Kamboja'])

# %%
"Indonesia merupakan negara dengan tingkat kematian bayi tertinggi dibandingkan dengan negara-negara tetangga. disusul oleh Filipina, Kamboja, Thailand, Malaysia, dan Singapura"

# %%
plt.figure(figsize=(15,10))
plt.plot(x,y3,'r',x,yM3,'g',x,yP3,'c',x,yS3,'b',x,yT3,'k',x,yK3,'y')
plt.title('Angka Kematian Balita dari tahun ke tahun')
plt.xlabel('Tahun')
plt.ylabel('Kematian Balita')
plt.grid(True)
plt.legend(['Indonesia','Malaysia','Filipina','Singapura','Thailand','Kamboja'])

# %%
"Tidak berbeda jauh dengan Angka kematian Bayi, Indonesia memiliki angka kematian Balita tertinggi dibandingkan dengan negara tetangga."
# Out:
# 'Tidak berbeda jauh dengan Angka kematian Bayi, Indonesia memiliki angka kematian Balita tertinggi dibandingkan dengan negara tetangga.'

# %%
plt.figure(figsize=(15,10))
plt.plot(x,y4,'r',x,yM4,'g',x,yP4,'c',x,yS4,'b',x,yT4,'k',x,yK4,'y')
plt.title('Angka Income Composition dari tahun ke tahun')
plt.xlabel('Tahun')
plt.ylabel('Income')
plt.grid(True)
plt.legend(['Indonesia','Malaysia','Filipina','Singapura','Thailand','Kamboja'])

# %%
"Ketujuh negara mengalami penigkatan pemerataaan ekonomi yang stabil, namun tidak terlalu cepat"
"Singapura adalah negara dengan pemerataan pendapatan tertinggi, danK Kamboja adalah negara dengan pemerataan pendidikan terendah"

# %%
plt.figure(figsize=(15,10))
plt.plot(x,y5,'r',x,yM5,'g',x,yP5,'c',x,yS5,'b',x,yT5,'k',x,yK5,'y')
plt.title('Angka Pendidikan dari tahun ke tahun')
plt.xlabel('Tahun')
plt.ylabel('Schooling')
plt.grid(True)
plt.legend(['Indonesia','Malaysia','Filipina','Singapura','Thailand','Kamboja'])

# %%
"Angka pendidikan merupakan hal yang paling menarik untuk dibahas."
"Malaysia sempat menyusul Singapura pada tahun 2005, namun kembali disusul oleh Singapura dalam hal pendidikan"
"Indonesia menyusul Filipina dalam isu Pendidikan, namun tidak dapat menyusul Malaysia"
# Out:
# 'Indonesia menyusul Filipina dalam isu Pendidikan, namun tidak dapat menyusul Malaysia'

# %%
"Kesimpulan"
# Out:
# 'KESIMPULAN:'

# %%
"Walaupun Pendidikan dan Ekonomi tidak berpengaruh secara langsung terhadap Angka Harapan Hidup, namun kedua variabel tersebut merupakan faktor penentu Angka Harapan Hidup. Pendidikan dapat mempengaruhi pilihan gaya hidup individu ataupun pengetahuan individu terhadap penyakit/bahaya kesehatan yang dapat mempengaruhi angka kematian. "
'>>REFERENSI: "Parents Knowledge of Danger Signs and Health Seeking Behavior in Newborn and Young Infant Illness in Tiro Afeta District, Southwest Ethiopia: A Community-based Study, Melkamu Berhane et al. " https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6308740/'
'>>REFERENSI: “Dietary Pattern and Food Intake Habit of the Underprivileged Children Residing in the Urban Slums: Tanvir Chowdhury Turin, Nahid Rumana, Nahid Shahana,”'
'>>REFERENSI: “Kebiasaan Makan Ibu dan Anak Usia 3-5 Tahun pada Kelompok Sosio-Ekonomi Tinggi dan Rendah di Kelurahan Rambutan dan Penggilingan, Jakarta Timur: Fatmah dan Nurasiah ”'

"Indonesia dapat memanfaatkan APBN dan APBD dalam sektor Pendidikan dan Pemerataan Ekonomi agar dapat kembali meningkatkan angka harapan hidup. dalam prosesnya, Indonesia dapat memanfaatkan hubungan Bilateral dengan Kamboja dan dapat dilakukan kerjasama dalam menurunkan angka kematian dewasa, dimana Kamboja dapat melakukannya dengan sangat efisien. selain itu, Indonesia juga dapat melakukan kerja sama dengan negara Thailand dan Singapura dalam pemerataan pendidikan. dimana Singapura selalu menempati posisi paling atas dan Thailand dapat meningkatkan angka sekolah secara signifikan ketimbang Indonesia."

"selain itu, Indonesia juga memiliki tantangan, dimana Indonesia memiliki angka kematian Bayi dan Balita tertinggi diantara negara-negara yang dikomparasi. sehingga, Indonesia perlu bergegas untuk melakukan pemerataan faskes dan pendidikan kesehatan ke daerah rural dan remote"

# %%
"Setelah membahas Angka Harapan Hidup dari sisi sosial ekonomi (Pendidikan dan Pendapatan), tentu faktor kesehatan dan sebaran penyakit menjadi bagian penting yang mempengaruhi kematian"
"namun, pada bagian ini, penulis hanya akan menjabarkan data, tanpa adanya analisa lanjutan terhadap data tersebut."
# Out:
# 'Setelah membahas Angka Harapan Hidup dari sisi sosial ekonomi (Pendidikan dan Pendapatan), tentu faktor kesehatan dan sebaran penyakit menjadi bagian penting yang mempengaruhi kematian'

# %%
plt.figure(figsize=(15,10))
plt.plot(x,y6,x,y7,x,y8,x,y9,x,y10)
plt.title('Angka Penyebaran Penyakit dari Tahun ke Tahun')
plt.xlabel('Tahun')
plt.ylabel('Sebaran')
plt.grid(True)
plt.legend(['Hepatitis B','Measles/Cacar','Polio','Difteri','HIV/AIDS'])

# %%
"dari data diatas, Measles/Cacar masih menjadi tantangan bagi Indonesia, melihat angkanya yang jauh lebih besar ketimbang penyakit lainnya"
# Out:
# 'dari data diatas, Measles/Cacar masih menjadi tantangan bagi Indonesia, melihat angkanya yang jauh lebih besar ketimbang penyakit lainnya'

# %%
plt.figure(figsize=(15,10))
plt.plot(x,y6,x,y8,x,y9,x,y10)
plt.title('Angka Penyebaran Penyakit dari Tahun ke Tahun')
plt.xlabel('Tahun')
plt.ylabel('Sebaran')
plt.grid(True)
plt.legend(['Hepatitis B','Polio','Difteri','HIV/AIDS'])

# %%
"Apabila Cacar/Measles keluarkan dari data, jumlah HIV/AIDS memiliki jumlah yang sedikit dan hampir mendekati 0. sedangkan Difteri, Polio, dan Hepatitis B masih menjadi tantangan bagi Indonesia, selain Cacar/Measles diatas."
"pada tahun 2013-2014, Indonesia berhasil menurunkan angka Polio dengan sangat signifikan"
